# %% [markdown]
# # Limitless Data Extraction

# %%
import requests
import bs4 as bs4
import json
import time

from random import choice

# %% [markdown]
# ## Environment Variables

# %%
BASE_URL = "https://pocket.limitlesstcg.com"
set_list = []
set_keys = []
card_list = []
dataset = []

session = requests.Session()
session.headers.update(
    {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36"
    }
)

# %% [markdown]
# ## Extracting Sets URLs

# %%
response = session.get(f"{BASE_URL}/cards")
if response.status_code == 200:
    content = bs4.BeautifulSoup(response.content, "html.parser")

    table = content.find("table", {"class": "sets-table"})
    sets = table.find_all("a")

    for set in sets:
        record = { "url": f"{BASE_URL}{set.get("href")}",
                   "name": ' '.join([x.strip() for x in set.text.strip().split('\n')])
                 }
        
        if record["url"] not in set_keys:
          set_keys.append(record["url"])
          set_list.append(record)
else:
    print(f"Failed to retrieve sets data from {BASE_URL}. Status code: {response.status_code}")
    exit(1)
    
print(f"Found {len(set_list)} sets.")
# Out:
# Found 8 sets.

# %% [markdown]
# ## Extracting Cards from Sets

# %%
for url in set_list:
    response = session.get(url["url"])
    if response.status_code == 200:
        content = bs4.BeautifulSoup(response.content, "html.parser")
        grid = content.find("div", {"class": "card-search-grid"})
        cards = grid.find_all("a")

        for row in cards:
            url_card = f"{BASE_URL}{row.get('href')}"
            img = row.img.get("src")
            card_list.append({"set": url, "img": img, "card": url_card, 'key': row.get('href')})
            
        print(f"Retrieved {len(cards)} cards from {url["name"]}")
        
    else:
        print(f"Failed to retrieve cards data from set {url["name"]}. Status code: {response.status_code}")
        
    time.sleep(20)
# Out:
# Retrieved 103 cards from Extradimensional Crisis A3a
# Retrieved 239 cards from Celestial Guardians A3
# Retrieved 111 cards from Shining Revelry A2b
# Retrieved 96 cards from Triumphant Light A2a
# Retrieved 207 cards from Space-Time Smackdown A2
# Retrieved 86 cards from Mythical Island A1a
# Retrieved 286 cards from Genetic Apex A1
# Retrieved 83 cards from Promo-A P-A

# %% [markdown]
# ## Extracting Cards Details

# %%
r = 1
dataset = []

for item in card_list:
    content = session.get(item["card"])
    card_page = bs4.BeautifulSoup(content.content, "html.parser")
    card = card_page.find("div", {"class": "card-details-main"})

    line1 = card.find("p", {"class": "card-text-title"})
    try:
        name, ptype, hp = [x.strip() for x in line1.text.split('-')]
    except:
        name = line1.text.strip()
        ptype = None
        hp = None

    line2 = card.find("p", {"class": "card-text-type"})
    try:
        card_type, stage, evolve = [x.strip() for x in line2.text.split("-")]
    except:
        try:
            card_type, stage = [x.strip() for x in line2.text.split("-")]
            evolve = "None"
        except:
            card_type = line2.text.strip()
            stage = None
            evolve = None

    ability = card.find("div", {"class": "card-text-ability"})
    if ability:
        try:
            ability_name = ability.find("p", {"class": "card-text-ability-info"}).text.strip()
            ability_text = ability.find("p", {"class": "card-text-ability-effect"}).text.strip()
        except:
            ability_name = None
            ability_text = None

    attacks = card.find_all("div", {"class": "card-text-attack"})
    card_attacks = []
    for attack in attacks:
        att_cost_name = attack.find("p", {"class": "card-text-attack-info"})
        att_effect = attack.find("p", {"class": "card-text-attack-effect"}).text.strip()
        card_attacks.append(
            [x.strip() for x in att_cost_name.text.split(" ") if x.strip() != ""]
            + [att_effect]
        )

    extras = card.find_all("p", {"class": "card-text-wrr"})
    extra_info = None
    if extras and len(extras) > 0:
      extra_info = [x.strip() for x in extras[0].text.split("\n")]
    
    record = {
        "id": item["key"].replace("/cards", ""),
        "name": name,
        "type": ptype,
        "hp": hp.replace("HP", "").strip() if hp else None,
        "card_type": card_type,
        "stage": stage,
        "evolve": " ".join([x.strip() for x in evolve.split("\n")]) if evolve else None,
        "ability": {"name": ability_name, "text": ability_text} if ability else None,
        "attacks": [
            {
                "cost": x[0],
                "name": " ".join(x[1:-2] if str.isnumeric(x[-2]) else x[1:-1]),
                "damage": x[-2] if str.isnumeric(x[-2]) else None,
                "effect": x[-1],
            }
            for x in card_attacks
        ],
        "weakness": extra_info[1].replace("Weakness: ","") if extra_info else None,
        "retreat_cost": extra_info[2].replace("Retreat: ","") if extra_info else None,
        "img": item["img"],
        "set": item["set"],
    }
    dataset.append(record)

    r += 1
    if r % 10 == 0:
        delayed = choice([1, 3, 5, 7])
        print(f"Processed {r} cards, sleeping for {delayed} seconds to avoid rate limiting.")
        time.sleep(delayed)
# Out:
# Processed 10 cards, sleeping for 3 seconds to avoid rate limiting.
# Processed 20 cards, sleeping for 5 seconds to avoid rate limiting.
# Processed 30 cards, sleeping for 5 seconds to avoid rate limiting.
# Processed 40 cards, sleeping for 1 seconds to avoid rate limiting.
# Processed 50 cards, sleeping for 7 seconds to avoid rate limiting.
# Processed 60 cards, sleeping for 7 seconds to avoid rate limiting.
# Processed 70 cards, sleeping for 5 seconds to avoid rate limiting.
# Processed 80 cards, sleeping for 3 seconds to avoid rate limiting.
# Processed 90 cards, sleeping for 1 seconds to avoid rate limiting.
# Processed 100 cards, sleeping for 1 seconds to avoid rate limiting.
# Processed 110 cards, sleeping for 3 seconds to avoid rate limiting.
# Processed 120 cards, sleeping for 5 seconds to avoid rate limiting.
# Processed 130 cards, sleeping for 7 seconds to avoid rate limiting.
# Processed 140 cards, sleeping for 1 seconds to avoid rate limiting.
# Processed 150 cards, sleeping for 3 seconds to avoid rate limiting.
# Processed 160 cards, sleeping for 3 seconds to avoid rate limiting.
# Processed 170 cards, sleeping for 1 seconds to avoid rate limiting.
# Processed 180 cards, sleeping for 7 seconds to avoid rate limiting.
# Processed 190 cards, sleeping for 1 seconds to avoid rate limiting.
# Processed 200 cards, sleeping for 1 seconds to avoid rate limiting.
# Processed 210 cards, sleeping for 7 seconds to avoid rate limiting.
# Processed 220 cards, sleeping for 7 seconds to avoid rate limiting.
# Processed 230 cards, sleeping for 7 seconds to avoid rate limiting.
# Processed 240 cards, sleeping for 7 seconds to avoid rate limiting.
# Processed 250 cards, sleeping for 7 seconds to avoid rate limiting.
# Processed 260 cards, sleeping for 5 seconds to avoid rate limiting.
# Processed 270 cards, sleeping for 7 seconds to avoid rate limiting.
# Processed 280 cards, sleeping for 7 seconds to avoid rate limiting.
# Processed 290 cards, sleeping for 3 seconds to avoid rate limiting.
# Processed 300 cards, sleeping for 7 seconds to avoid rate limiting.
# Processed 310 cards, sleeping for 7 seconds to avoid rate limiting.
# Processed 320 cards, sleeping for 5 seconds to avoid rate limiting.
# Processed 330 cards, sleeping for 3 seconds to avoid rate limiting.
# Processed 340 cards, sleeping for 7 seconds to avoid rate limiting.
# Processed 350 cards, sleeping for 5 seconds to avoid rate limiting.
# Processed 360 cards, sleeping for 1 seconds to avoid rate limiting.
# Processed 370 cards, sleeping for 3 seconds to avoid rate limiting.
# Processed 380 cards, sleeping for 5 seconds to avoid rate limiting.
# Processed 390 cards, sleeping for 5 seconds to avoid rate limiting.
# Processed 400 cards, sleeping for 7 seconds to avoid rate limiting.
# Processed 410 cards, sleeping for 5 seconds to avoid rate limiting.
# Processed 420 cards, sleeping for 5 seconds to avoid rate limiting.
# Processed 430 cards, sleeping for 1 seconds to avoid rate limiting.
# Processed 440 cards, sleeping for 1 seconds to avoid rate limiting.
# Processed 450 cards, sleeping for 5 seconds to avoid rate limiting.
# Processed 460 cards, sleeping for 7 seconds to avoid rate limiting.
# Processed 470 cards, sleeping for 7 seconds to avoid rate limiting.
# Processed 480 cards, sleeping for 3 seconds to avoid rate limiting.
# Processed 490 cards, sleeping for 3 seconds to avoid rate limiting.
# Processed 500 cards, sleeping for 3 seconds to avoid rate limiting.
# Processed 510 cards, sleeping for 3 seconds to avoid rate limiting.
# Processed 520 cards, sleeping for 3 seconds to avoid rate limiting.
# Processed 530 cards, sleeping for 7 seconds to avoid rate limiting.
# Processed 540 cards, sleeping for 7 seconds to avoid rate limiting.
# Processed 550 cards, sleeping for 7 seconds to avoid rate limiting.
# Processed 560 cards, sleeping for 7 seconds to avoid rate limiting.
# Processed 570 cards, sleeping for 7 seconds to avoid rate limiting.
# Processed 580 cards, sleeping for 3 seconds to avoid rate limiting.
# Processed 590 cards, sleeping for 3 seconds to avoid rate limiting.
# Processed 600 cards, sleeping for 7 seconds to avoid rate limiting.
# Processed 610 cards, sleeping for 3 seconds to avoid rate limiting.
# Processed 620 cards, sleeping for 7 seconds to avoid rate limiting.
# Processed 630 cards, sleeping for 1 seconds to avoid rate limiting.
# Processed 640 cards, sleeping for 1 seconds to avoid rate limiting.
# Processed 650 cards, sleeping for 7 seconds to avoid rate limiting.
# Processed 660 cards, sleeping for 3 seconds to avoid rate limiting.
# Processed 670 cards, sleeping for 3 seconds to avoid rate limiting.
# Processed 680 cards, sleeping for 3 seconds to avoid rate limiting.
# Processed 690 cards, sleeping for 1 seconds to avoid rate limiting.
# Processed 700 cards, sleeping for 7 seconds to avoid rate limiting.
# Processed 710 cards, sleeping for 1 seconds to avoid rate limiting.
# Processed 720 cards, sleeping for 3 seconds to avoid rate limiting.
# Processed 730 cards, sleeping for 3 seconds to avoid rate limiting.
# Processed 740 cards, sleeping for 5 seconds to avoid rate limiting.
# Processed 750 cards, sleeping for 5 seconds to avoid rate limiting.
# Processed 760 cards, sleeping for 3 seconds to avoid rate limiting.
# Processed 770 cards, sleeping for 3 seconds to avoid rate limiting.
# Processed 780 cards, sleeping for 1 seconds to avoid rate limiting.
# Processed 790 cards, sleeping for 5 seconds to avoid rate limiting.
# Processed 800 cards, sleeping for 3 seconds to avoid rate limiting.
# Processed 810 cards, sleeping for 1 seconds to avoid rate limiting.
# Processed 820 cards, sleeping for 5 seconds to avoid rate limiting.
# Processed 830 cards, sleeping for 5 seconds to avoid rate limiting.
# Processed 840 cards, sleeping for 7 seconds to avoid rate limiting.
# Processed 850 cards, sleeping for 5 seconds to avoid rate limiting.
# Processed 860 cards, sleeping for 3 seconds to avoid rate limiting.
# Processed 870 cards, sleeping for 7 seconds to avoid rate limiting.
# Processed 880 cards, sleeping for 3 seconds to avoid rate limiting.
# Processed 890 cards, sleeping for 5 seconds to avoid rate limiting.
# Processed 900 cards, sleeping for 5 seconds to avoid rate limiting.
# Processed 910 cards, sleeping for 3 seconds to avoid rate limiting.
# Processed 920 cards, sleeping for 7 seconds to avoid rate limiting.
# Processed 930 cards, sleeping for 1 seconds to avoid rate limiting.
# Processed 940 cards, sleeping for 5 seconds to avoid rate limiting.
# Processed 950 cards, sleeping for 5 seconds to avoid rate limiting.
# Processed 960 cards, sleeping for 7 seconds to avoid rate limiting.
# Processed 970 cards, sleeping for 1 seconds to avoid rate limiting.
# Processed 980 cards, sleeping for 5 seconds to avoid rate limiting.
# Processed 990 cards, sleeping for 7 seconds to avoid rate limiting.
# Processed 1000 cards, sleeping for 5 seconds to avoid rate limiting.
# Processed 1010 cards, sleeping for 1 seconds to avoid rate limiting.
# Processed 1020 cards, sleeping for 3 seconds to avoid rate limiting.
# Processed 1030 cards, sleeping for 3 seconds to avoid rate limiting.
# Processed 1040 cards, sleeping for 7 seconds to avoid rate limiting.
# Processed 1050 cards, sleeping for 1 seconds to avoid rate limiting.
# Processed 1060 cards, sleeping for 5 seconds to avoid rate limiting.
# Processed 1070 cards, sleeping for 7 seconds to avoid rate limiting.
# Processed 1080 cards, sleeping for 3 seconds to avoid rate limiting.
# Processed 1090 cards, sleeping for 7 seconds to avoid rate limiting.
# Processed 1100 cards, sleeping for 3 seconds to avoid rate limiting.
# Processed 1110 cards, sleeping for 3 seconds to avoid rate limiting.
# Processed 1120 cards, sleeping for 1 seconds to avoid rate limiting.
# Processed 1130 cards, sleeping for 7 seconds to avoid rate limiting.
# Processed 1140 cards, sleeping for 5 seconds to avoid rate limiting.
# Processed 1150 cards, sleeping for 7 seconds to avoid rate limiting.
# Processed 1160 cards, sleeping for 5 seconds to avoid rate limiting.
# Processed 1170 cards, sleeping for 5 seconds to avoid rate limiting.
# Processed 1180 cards, sleeping for 7 seconds to avoid rate limiting.
# Processed 1190 cards, sleeping for 7 seconds to avoid rate limiting.
# Processed 1200 cards, sleeping for 3 seconds to avoid rate limiting.
# Processed 1210 cards, sleeping for 1 seconds to avoid rate limiting.

# %%
with open("../data/cards.json", "w") as f:
    json.dump(dataset, f, indent=4)
    print(f"Data saved to limitless_cards.json")
    
print(f"Total cards retrieved: {len(dataset)}")
# Out:
# Data saved to limitless_cards.json
# Total cards retrieved: 1211
